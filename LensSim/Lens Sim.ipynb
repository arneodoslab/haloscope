# %%
import numpy as np
import matplotlib.pyplot as plt
import 

# Generates a lens

# A lens has a center point O(0,0) from that we can define two circles by using two points. 

class Lens:
    
    def __init__(self,pos):
